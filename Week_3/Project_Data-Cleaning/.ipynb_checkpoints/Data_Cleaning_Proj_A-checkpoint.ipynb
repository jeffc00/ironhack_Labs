# %%
import numpy as np
import pandas as pd
import re

# %%
attacks = pd.read_csv('../Project_Data-Cleaning/data/attacks.csv', encoding='latin1' )

# %%
attacks.head()
# Out:
#   Case Number         Date    Year        Type    Country             Area  \
# 0  2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1  2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex   ...  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F  ...
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F  ...
# 2                    Habush, Oahu      Surfing      John Denges    M  ...
# 3              Arrawarra Headland      Surfing             male    M  ...
# 4                        La Ticla  Free diving   Gustavo Ramos     M  ...
#
# ...

# %%
attacks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25723 entries, 0 to 25722
# Data columns (total 24 columns):
# Case Number               8702 non-null object
# Date                      6302 non-null object
# Year                      6300 non-null float64
# Type                      6298 non-null object
# Country                   6252 non-null object
# Area                      5847 non-null object
# Location                  5762 non-null object
# Activity                  5758 non-null object
# Name                      6092 non-null object
# Sex                       5737 non-null object
# Age                       3471 non-null object
# Injury                    6274 non-null object
# Fatal (Y/N)               5763 non-null object
# Time                      2948 non-null object
# Species                   3464 non-null object
# Investigator or Source    6285 non-null object
# pdf                       6302 non-null object
# href formula              6301 non-null object
# ...

# %%
attacks.drop_duplicates(inplace=True)

# %%
attacks.reset_index(inplace=True)

# %%
attacks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6312 entries, 0 to 6311
# Data columns (total 25 columns):
# index                     6312 non-null int64
# Case Number               6310 non-null object
# Date                      6302 non-null object
# Year                      6300 non-null float64
# Type                      6298 non-null object
# Country                   6252 non-null object
# Area                      5847 non-null object
# Location                  5762 non-null object
# Activity                  5758 non-null object
# Name                      6092 non-null object
# Sex                       5737 non-null object
# Age                       3471 non-null object
# Injury                    6274 non-null object
# Fatal (Y/N)               5763 non-null object
# Time                      2948 non-null object
# Species                   3464 non-null object
# Investigator or Source    6285 non-null object
# pdf                       6302 non-null object
# ...

# %%
attacks.drop(columns='index', inplace=True)

# %%
attacks['Unnamed: 22'].isnull().sum()
# Out:
# 6311

# %%
attacks.drop(columns=['Unnamed: 22', 'Unnamed: 23'], axis=1, inplace=True)

# %%
pd.options.display.max_rows
# Out:
# 20

# %%
pd.options.display.max_rows = 20

# %%
attacks.head()
# Out:
#   Case Number         Date    Year        Type    Country             Area  \
# 0  2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1  2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex   ...  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F  ...
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F  ...
# 2                    Habush, Oahu      Surfing      John Denges    M  ...
# 3              Arrawarra Headland      Surfing             male    M  ...
# 4                        La Ticla  Free diving   Gustavo Ramos     M  ...
#
# ...

# %%
#Investigando 'Fatal Y/N'

# %%
attacks['Fatal (Y/N)'].unique()
# Out:
# array(['N', 'Y', nan, 'M', 'UNKNOWN', '2017', ' N', 'N ', 'y'],
#       dtype=object)

# %%
attacks['Fatal (Y/N)'].iloc[2267] = 'N'

# %%
attacks[attacks['Fatal (Y/N)'] == 'UNKNOWN']
# Out:
#        Case Number           Date    Year        Type    Country  \
# 624     2013.09.08    08-Sep-2013  2013.0  Unprovoked        USA
# 2250    1997.06.07    07-Jun-1997  1997.0  Unprovoked     BRAZIL
# 2260    1997.02.21    21-Feb-1997  1997.0  Unprovoked        USA
# 2295    1996.07.14    14-Jul-1996  1996.0  Unprovoked        USA
# 2307  1996.04.28.b    28-Apr-1996  1996.0  Unprovoked        USA
# ...            ...            ...     ...         ...        ...
# 6167  1617.00.00.R  Reported 1617  1617.0  Unprovoked      INDIA
# 6169    1595.00.00           1595  1595.0  Unprovoked      INDIA
# 6171    1555.00.00           1555  1555.0  Unprovoked        NaN
# 6172    1554.00.00       Ca. 1554  1554.0  Unprovoked     FRANCE
# 6277       ND.0025    Before 1927     0.0  Unprovoked  AUSTRALIA
#
#                    Area                            Location  \
# 624      South Carolina  St. Helena Island, Beaufort County
# 2250     Rio de Janeiro          Copacabana, Rio de Janeiro
# ...

# %%
attacks['Fatal (Y/N)'].replace({'M':'N',' N':'N', 'N ':'N', 'y':'Y','2017':np.nan}, inplace=True)

# %%
attacks['Fatal (Y/N)'].unique()
# Out:
# array(['N', 'Y', nan, 'UNKNOWN'], dtype=object)

# %%
# Investigando Activity

# %%
attacks['Activity'].describe()
# Out:
# count        5758
# unique       1532
# top       Surfing
# freq          971
# Name: Activity, dtype: object

# %%
attacks['Activity'].unique()
# Out:
# array(['Paddling', 'Standing', 'Surfing', ...,
#        'Crew swimming alongside their anchored ship',
#        '4 men were bathing', 'Wreck of  large double sailing canoe'],
#       dtype=object)

# %%
attacks['Name'].describe()
# Out:
# count     6092
# unique    5230
# top       male
# freq       550
# Name: Name, dtype: object

# %%
attacks['Name'] = attacks['Name'].apply(str)

# %%
attacks['Name'].replace({' male':np.nan, 'male':np.nan, 'female':np.nan}, inplace=True)

# %%
attacks['Name'].apply(lambda x : re.findall(r'[\d\s\w]male.*',x)).sum()
# Out:
# ['emale x 2',
#  ' males',
#  'emale diver',
#  ' male',
#  'emale',
#  ' male from Miami',
#  ' male 2',
#  ' male from Waikato',
#  ' male',
#  'emale',
#  'emale)',
#  ' male',
#  ' male',
#  'emale)',
#  ' male',
#  ' male',
#  'emale, possibly victim of a small plane crash in the vicinity',
#  ' male from Muitoa',
#  ' male',
#  ' male',
#  ' male',
#  ' male',
#  ' male',
#  ' male',
#  ' male',
#  'emale)',
#  'emale)',
#  'emale - rescuer)',
#  'emale)',
#  'emale)',
#  ' male',
#  ' male',
#  ' males',
#  ' male',
#  ' male',
#  'emale)',
#  'emale',
#  'emale',
#  ' males',
#  ' male',
#  ' males',
#  ' male ',
#  ' male',
#  ' males',
#  ' males admitted to Memorial Hospital emergency room this month',
#  ' male',
#  ' male, one of crew of pearl culture survey ship',
#  ' males',
#  ' male',
#  ' male',
#  ' males',
#  ' male',
#  ' males',
#  ' males',
#  ' male from the Second Seabee Battalion',
#  ' males',
#  ' males',
#  ' males',
#  'emale',
# ...

# %%
# Investigando coluna Sex

# %%
attacks.rename(columns={'Sex ':'Sex'}, inplace=True)

# %%
attacks['Sex'].unique()
# Out:
# array(['F', 'M', nan, 'M ', 'lli', 'N', '.'], dtype=object)

# %%
attacks[attacks['Sex'].isnull()]
# Out:
#        Case Number                  Date    Year          Type        Country  \
# 32      2018.04.09           09-Apr-2018  2018.0    Unprovoked  NEW CALEDONIA
# 59    2017.11.25.R  Reported 25-Nov-2017  2017.0  Sea Disaster          LIBYA
# 86      2017.09.14              Sep-2017  2017.0       Boating      AUSTRALIA
# 124     2017.07.02           02-Jul-2017  2017.0       Invalid        COMOROS
# 154   2017.04.17.b           17-Apr-2017  2017.0    Unprovoked            USA
# ...            ...                   ...     ...           ...            ...
# 6307             0                   NaN     NaN           NaN            NaN
# 6308             0                   NaN     NaN           NaN            NaN
# 6309             0                   NaN     NaN           NaN            NaN
# 6310           NaN                   NaN     NaN           NaN            NaN
# 6311            xx                   NaN     NaN           NaN            NaN
#
# ...

# %%
attacks['Sex'].replace({'M ':'M', 'lli':np.nan, 'N':'M', '.':np.nan}, inplace=True)

# %%
attacks['Sex'].unique()
# Out:
# array(['F', 'M', nan], dtype=object)

# %%
attacks.loc[0]['href']
# Out:
# 'http://sharkattackfile.net/spreadsheets/pdf_directory/2018.06.25-Wolfe.pdf'

# %%
href = attacks[attacks['href formula'] != attacks['href']]

# %%
href.reset_index()
# Out:
#     index Case Number         Date    Year        Type           Country  \
# 0      50  2018.01.13  13-Jan-2018  2018.0  Unprovoked         AUSTRALIA
# 1      96  2017.08.29  29-Aug-2017  2017.0  Unprovoked         AUSTRALIA
# 2     131  2017.06.05   2017.06.05  2017.0  Unprovoked  FRENCH POLYNESIA
# 3     133  2017.06.11  11-Jun-2017  2017.0  Unprovoked         AUSTRALIA
# 4     141  2017.05.27  27-May-2017  2017.0     Invalid         AUSTRALIA
# ..    ...         ...          ...     ...         ...               ...
# 65   6307           0          NaN     NaN         NaN               NaN
# 66   6308           0          NaN     NaN         NaN               NaN
# 67   6309           0          NaN     NaN         NaN               NaN
# 68   6310         NaN          NaN     NaN         NaN               NaN
# 69   6311          xx          NaN     NaN         NaN               NaN
#
#                  Area                    Location       Activity  \
# ...

# %%
href['href'].iloc[0]
# Out:
# 'http://sharkattackfile.net/spreadsheets/pdf_directory/http://sharkattackfile.net/spreadsheets/pdf_directory/2018.01.13-Stewart.pdf'

# %%
for i in range(len(href)):
    print(i)
    print(href['href'].iloc[i])
    print(href['href formula'].iloc[i])
# Out:
# 0
# http://sharkattackfile.net/spreadsheets/pdf_directory/http://sharkattackfile.net/spreadsheets/pdf_directory/2018.01.13-Stewart.pdf
# http://sharkattackfile.net/spreadsheets/pdf_directory/2018.01.13-Stewart.pdf
# 1
# http://sharkattackfile.net/spreadsheets/pdf_directory/http://sharkattackfile.net/spreadsheets/pdf_directory/2017.08.27-Brundler.pdf
# http://sharkattackfile.net/spreadsheets/pdf_directory/2017.08.27-Brundler.pdf
# 2
# http://sharkattackfile.net/spreadsheets/pdf_directory/http://sharkattackfile.net/spreadsheets/pdf_directory/2017.06.05-FrenchPolynesia.pdf
# http://sharkattackfile.net/spreadsheets/pdf_directory/2017.06.05-FrenchPolynesia.pdf
# 3
# http://sharkattackfile.net/spreadsheets/pdf_directory/http://sharkattackfile.net/spreadsheets/pdf_directory/2017.06.11-Goff.pdf
# http://sharkattackfile.net/spreadsheets/pdf_directory/2017.06.11-Goff.pdf
# 4
# ...

# %%
attacks.drop(columns='href', axis=1, inplace=True)

# %%
attacks.rename(columns={'href formula':'Link'}, inplace=True)

# %%
attacks.dropna(thresh=9, axis=0, inplace=True)

# %%
attacks.reset_index(inplace=True)

# %%
# Analisando Type

# %%
attacks['Type'].describe()
# Out:
# count           6298
# unique             8
# top       Unprovoked
# freq            4595
# Name: Type, dtype: object

# %%
attacks['Type'].unique()
# Out:
# array(['Boating', 'Unprovoked', 'Invalid', 'Provoked', 'Questionable',
#        'Sea Disaster', nan, 'Boat', 'Boatomg'], dtype=object)

# %%
attacks[attacks['Type'] == 'Boatomg']
# Out:
#       index   Case Number         Date    Year     Type      Country  \
# 1152   1152  2009.03.01.b  01-Mar-2009  2009.0  Boatomg  NEW ZEALAND
#
#               Area  Location Activity  \
# 1152  North Island  Taranaki  Fishing
#
#                                                  Name  ...  \
# 1152  boat, occupants: Boyd Rutherford & Hamish Roper  ...
#
#                                            Injury Fatal (Y/N) Time Species   \
# 1152  No injury to occupants, shark bit propeller           N  NaN      NaN
#
#              Investigator or Source                      pdf  \
# 1152  Taranaki Daily News, 3/3/2009  2009.03.01-Taranaki.pdf
#
#                                                    Link Case Number.1  \
# 1152  http://sharkattackfile.net/spreadsheets/pdf_di...  2009.03.01.b
#
#      Case Number.2 original order
# 1152  2009.03.01.b         5151.0
#
# [1 rows x 22 columns]

# %%
attacks['Type'].replace({'Boatomg':'Boating'}, inplace=True)

# %%
attacks['Type'].unique()
# Out:
# array(['Boating', 'Unprovoked', 'Invalid', 'Provoked', 'Questionable',
#        'Sea Disaster', nan, 'Boat'], dtype=object)

# %%
attacks[attacks['Type'].isnull()]
# Out:
#       index   Case Number                  Date    Year Type    Country  \
# 85       85  2017.09.15.a           15-Sep-2017  2017.0  NaN      SAMOA
# 382     382    2015.07.27           27-Jul-2015  2015.0  NaN  AUSTRALIA
# 4867   4867  1936.09.11.R  Reported 11-Sep-1936  1936.0  NaN    VIETNAM
# 5705   5705  1890.03.03.R  Reported 03-Mar-1890  1890.0  NaN     CEYLON
#
#                Area          Location           Activity           Name  ...  \
# 85     Upolu Island         Nofoalii            Fishing            nan  ...
# 382        Victoria  Tyrendarra Beach            Surfing            nan  ...
# 4867            NaN            Saigon  Wreck of a sampam         8 crew  ...
# 5705            NaN               NaN             Diving  a pearl diver  ...
#
#                           Injury Fatal (Y/N)   Time Species   \
# 85    Injuries to hands and legs           N  Night      NaN
# 382               Injury to hand         NaN    NaN      NaN
# ...

# %%
attacks['Age'].unique()
# Out:
# array(['57', '11', '48', nan, '18', '52', '15', '12', '32', '10', '21',
#        '34', '30', '60', '33', '29', '54', '41', '37', '56', '19', '25',
#        '69', '38', '55', '35', '46', '45', '14', '40s', '28', '20', '24',
#        '26', '49', '22', '7', '31', '17', '40', '13', '42', '3', '8',
#        '50', '16', '82', '73', '20s', '68', '51', '39', '58', 'Teen',
#        '47', '61', '65', '36', '66', '43', '60s', '9', '72', '59', '6',
#        '27', '64', '23', '71', '44', '62', '63', '70', '18 months', '53',
#        '30s', '50s', 'teen', '77', '74', '28 & 26', '5', '86', '18 or 20',
#        '12 or 13', '46 & 34', '28, 23 & 30', 'Teens', '36 & 26',
#        '8 or 10', '84', '\xa0 ', ' ', '30 or 36', '6½', '21 & ?', '75',
#        '33 or 37', 'mid-30s', '23 & 20', ' 30', '7      &    31', ' 28',
#        '20?', "60's", '32 & 30', '16 to 18', '87', '67', 'Elderly',
#        'mid-20s', 'Ca. 33', '74 ', '45 ', '21 or 26', '20 ', '>50',
# ...

# %%
attacks['Age']
# Out:
# 0        57
# 1        11
# 2        48
# 3       NaN
# 4       NaN
#        ...
# 6297    NaN
# 6298    NaN
# 6299    NaN
# 6300    NaN
# 6301     15
# Name: Age, Length: 6302, dtype: object

# %%
attacks['Age'] = attacks['Age'].apply(str)

# %%
attacks['Age'].apply(lambda x : re.findall(r'\d+s',x)).sum()
# Out:
# ['40s',
#  '20s',
#  '40s',
#  '60s',
#  '40s',
#  '20s',
#  '30s',
#  '50s',
#  '30s',
#  '20s',
#  '30s',
#  '20s',
#  '30s',
#  '30s',
#  '30s',
#  '30s',
#  '30s',
#  '20s',
#  '20s',
#  '20s',
#  '20s',
#  '50s']

# %%
attacks['Age'].apply(lambda x : re.findall(r'[^\d\w]+',x)).sum()
# Out:
# [' ',
#  ' & ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' & ',
#  ', ',
#  ' & ',
#  ' & ',
#  ' ',
#  ' ',
#  '\xa0 ',
#  ' ',
#  ' ',
#  ' ',
#  ' & ?',
#  ' ',
#  ' ',
#  '-',
#  ' & ',
#  ' ',
#  '      &    ',
#  ' ',
#  '?',
#  "'",
#  ' & ',
#  ' ',
#  ' ',
#  '-',
#  '. ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  '>',
#  ' ',
#  ' ',
#  ' & ',
#  '? & ',
#  ' ',
#  ' ',
#  ' ',
#  ' & ',
#  '(',
#  ')',
#  ' & ',
#  ' ',
#  ' ',
#  ', ',
#  ', ',
#  ', ',
#  ',  ? & ',
#  ', ',
#  ',',
#  ' & ',
#  ' & ',
#  ' & ',
#  ' & ',
#  '"',
#  '-',
#  '"',
#  ' ',
#  ' ',
#  ' & ',
#  ' & ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  '"',
#  '"',
#  ' ',
#  ' ',
#  ' & ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' & ',
#  '  ',
#  '.',
#  '.',
#  '?    &   ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ']

# %%
attacks['Age'] = attacks['Age'].str.replace(r'[^\d\w]+', '')

# %%
attacks['Age'].replace({'MAKELINEGREEN':np.nan}, inplace=True)

# %%
attacks['Age'].unique()
# Out:
# array(['57', '11', '48', 'nan', '18', '52', '15', '12', '32', '10', '21',
#        '34', '30', '60', '33', '29', '54', '41', '37', '56', '19', '25',
#        '69', '38', '55', '35', '46', '45', '14', '40s', '28', '20', '24',
#        '26', '49', '22', '7', '31', '17', '40', '13', '42', '3', '8',
#        '50', '16', '82', '73', '20s', '68', '51', '39', '58', 'Teen',
#        '47', '61', '65', '36', '66', '43', '60s', '9', '72', '59', '6',
#        '27', '64', '23', '71', '44', '62', '63', '70', '18months', '53',
#        '30s', '50s', 'teen', '77', '74', '2826', '5', '86', '18or20',
#        '12or13', '4634', '282330', 'Teens', '3626', '8or10', '84', '',
#        '30or36', '6½', '75', '33or37', 'mid30s', '2320', '731', '3230',
#        '16to18', '87', '67', 'Elderly', 'mid20s', 'Ca33', '21or26',
#        '18to22', 'adult', '912', '9months', '25to35', '2326', '1', '3337',
#        '25or28', '3767352727', '21342435', '3032', '5030', '1735', 'X',
# ...

# %%
# Case Number

# %%
attacks[attacks['Case Number.1'] != attacks['Case Number']]
# Out:
#        Case Number                                  Date    Year  \
# 34      2018.04.03                           03-Apr-2018  2018.0
# 117   2017.07.20.a                           20-Jul-2017  2017.0
# 144     2017.05.06                           05-May-2017  2017.0
# 217     2016.09.15                           16-Sep-2016  2016.0
# 314   2016.01.24.b                           24-Jan-2016  2016.0
# 334     2015.12.23                           07-Nov-2015  2015.0
# 339   2015.10.28.a                           28-Oct-2015  2015.0
# 390     2015.07-10                           10-Jul-2015  2015.0
# 560     2014.05.04                           04-May-2014  2014.0
# 3522    1967.07.05                           05-Jul-1967  1967.0
# 3795  1962,08.30.b                           30-Aug-1962  1962.0
# 3880  1961.09.02.R                  Reported 06-Sep-1961  1961.0
# 4403    1952.08.05                           05-Aug-1952  1952.0
# ...

# %%
attacks['Case Number'].iloc[5488] = '1905.09.06'
# Out:
# /home/rob/.local/lib/python3.7/site-packages/pandas/core/indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)

# %%
attacks[attacks['Case Number'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Case Number, Date, Year, Type, Country, Area, Location, Activity, Name, Sex, Age, Injury, Fatal (Y/N), Time, Species, Investigator or Source, pdf, Link, Case Number.1, Case Number.2, original order]
# Index: []
#
# [0 rows x 21 columns]

# %%
attacks.drop(columns=['Case Number.1','Case Number.2'], inplace=True)

# %%
attacks.head()
# Out:
#   Case Number         Date    Year        Type    Country             Area  \
# 0  2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1  2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex  Age  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe   F   57
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely    F   11
# 2                    Habush, Oahu      Surfing      John Denges   M   48
# 3              Arrawarra Headland      Surfing              nan   M  nan
# 4                        La Ticla  Free diving   Gustavo Ramos    M  nan
#
#                                               Injury Fatal (Y/N)  \
# ...

# %%
attacks['Year'].unique()
# Out:
# array([2018., 2017.,   nan, 2016., 2015., 2014., 2013., 2012., 2011.,
#        2010., 2009., 2008., 2007., 2006., 2005., 2004., 2003., 2002.,
#        2001., 2000., 1999., 1998., 1997., 1996., 1995., 1984., 1994.,
#        1993., 1992., 1991., 1990., 1989., 1969., 1988., 1987., 1986.,
#        1985., 1983., 1982., 1981., 1980., 1979., 1978., 1977., 1976.,
#        1975., 1974., 1973., 1972., 1971., 1970., 1968., 1967., 1966.,
#        1965., 1964., 1963., 1962., 1961., 1960., 1959., 1958., 1957.,
#        1956., 1955., 1954., 1953., 1952., 1951., 1950., 1949., 1948.,
#        1848., 1947., 1946., 1945., 1944., 1943., 1942., 1941., 1940.,
#        1939., 1938., 1937., 1936., 1935., 1934., 1933., 1932., 1931.,
#        1930., 1929., 1928., 1927., 1926., 1925., 1924., 1923., 1922.,
#        1921., 1920., 1919., 1918., 1917., 1916., 1915., 1914., 1913.,
#        1912., 1911., 1910., 1909., 1908., 1907., 1906., 1905., 1904.,
# ...

# %%
attacks[attacks['Year'] == 0]
# Out:
#      Case Number           Date  Year          Type             Country  \
# 6177   0000.0214   Ca. 214 B.C.   0.0    Unprovoked                 NaN
# 6178   0000.0336  Ca. 336.B.C..   0.0    Unprovoked              GREECE
# 6179   0000.0493       493 B.C.   0.0  Sea Disaster              GREECE
# 6180   0000.0725   Ca. 725 B.C.   0.0  Sea Disaster               ITALY
# 6181     ND-0154    Before 1939   0.0    Unprovoked              CANADA
# ...          ...            ...   ...           ...                 ...
# 6297     ND.0005    Before 1903   0.0    Unprovoked           AUSTRALIA
# 6298     ND.0004    Before 1903   0.0    Unprovoked           AUSTRALIA
# 6299     ND.0003      1900-1905   0.0    Unprovoked                 USA
# 6300     ND.0002      1883-1889   0.0    Unprovoked              PANAMA
# 6301     ND.0001      1845-1853   0.0    Unprovoked  CEYLON (SRI LANKA)
#
#                    Area                                           Location  \
# ...

# %%
a = list(attacks.columns)

# %%
a[0] = 'original order'

# %%
a[18] = 'Case Number'

# %%
b = ['original order', 'Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location', 'Activity', 'Name','Sex', 'Age','Injury', 'Fatal (Y/N)', 'Time', 'Species', 'Investigator or Source', 'pdf','Link']

# %%
attacks[b]
# Out:
#       original order Case Number         Date    Year        Type  \
# 0             6303.0  2018.06.25  25-Jun-2018  2018.0     Boating
# 1             6302.0  2018.06.18  18-Jun-2018  2018.0  Unprovoked
# 2             6301.0  2018.06.09  09-Jun-2018  2018.0     Invalid
# 3             6300.0  2018.06.08  08-Jun-2018  2018.0  Unprovoked
# 4             6299.0  2018.06.04  04-Jun-2018  2018.0    Provoked
# ...              ...         ...          ...     ...         ...
# 6297             6.0     ND.0005  Before 1903     0.0  Unprovoked
# 6298             5.0     ND.0004  Before 1903     0.0  Unprovoked
# 6299             4.0     ND.0003    1900-1905     0.0  Unprovoked
# 6300             3.0     ND.0002    1883-1889     0.0  Unprovoked
# 6301             2.0     ND.0001    1845-1853     0.0  Unprovoked
#
#                  Country               Area  \
# 0                    USA         California
# 1                    USA            Georgia
# ...

# %%
attacks.head()
# Out:
#   Case Number         Date    Year        Type    Country             Area  \
# 0  2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1  2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex  Age  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe   F   57
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely    F   11
# 2                    Habush, Oahu      Surfing      John Denges   M   48
# 3              Arrawarra Headland      Surfing              nan   M  nan
# 4                        La Ticla  Free diving   Gustavo Ramos    M  nan
#
#                                               Injury Fatal (Y/N)  \
# ...

# %%
attacks['Time'].unique()
# Out:
# array(['18h00', '14h00  -15h00', '07h45', 'nan', 'Late afternoon',
#        '17h00', '14h00', 'Morning', '15h00', '08h15', '11h00', '10h30',
#        '10h40', '16h50', '07h00', '09h30', 'Afternoon', '21h50', '09h40',
#        '08h00', '17h35', '15h30', '07h30', '19h00, Dusk', 'Night',
#        '16h00', '15h01', '12h00', '13h45', '23h30', '09h00', '14h30',
#        '18h30', '12h30', '16h30', '18h45', '06h00', '10h00', '10h44',
#        '13h19', 'Midday', '13h30', '10h45', '11h20', '11h45', '19h30',
#        '08h30', '15h45', 'Shortly before 12h00', '17h34', '17h10',
#        '11h15', '08h50', '17h45', '13h00', '10h20', '13h20', '02h00',
#        '09h50', '11h30', '17h30', '9h00', '10h43', 'After noon', '15h15',
#        '15h40', '19h05', '1300', '14h30 / 15h30', '22h00', '16h20',
#        '14h34', '15h25', '14h55', '17h46', 'Morning ', '15h49', '19h00',
#        'Midnight', '09h30 / 10h00', '10h15', '18h15', '04h00', '14h50',
# ...

# %%
attacks['Time'] = attacks['Time'].apply(str)

# %%
attacks['Time'].apply(lambda x: re.findall(r'^F\w+.*',x)).sum()
# Out:
# ['FATAL  (Wire netting installed at local beaches after this incident.)']

# %%
attacks['Time'] = attacks['Time'].str.replace('^F\w+.*', ' ')

# %%
attacks['Time'].unique()
# Out:
# array(['18h00', '14h00  -15h00', '07h45', 'nan', 'Late afternoon',
#        '17h00', '14h00', 'Morning', '15h00', '08h15', '11h00', '10h30',
#        '10h40', '16h50', '07h00', '09h30', 'Afternoon', '21h50', '09h40',
#        '08h00', '17h35', '15h30', '07h30', '19h00, Dusk', 'Night',
#        '16h00', '15h01', '12h00', '13h45', '23h30', '09h00', '14h30',
#        '18h30', '12h30', '16h30', '18h45', '06h00', '10h00', '10h44',
#        '13h19', 'Midday', '13h30', '10h45', '11h20', '11h45', '19h30',
#        '08h30', '15h45', 'Shortly before 12h00', '17h34', '17h10',
#        '11h15', '08h50', '17h45', '13h00', '10h20', '13h20', '02h00',
#        '09h50', '11h30', '17h30', '9h00', '10h43', 'After noon', '15h15',
#        '15h40', '19h05', '1300', '14h30 / 15h30', '22h00', '16h20',
#        '14h34', '15h25', '14h55', '17h46', 'Morning ', '15h49', '19h00',
#        'Midnight', '09h30 / 10h00', '10h15', '18h15', '04h00', '14h50',
# ...

# %%
attacks[attacks['Year'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Case Number, Date, Year, Type, Country, Area, Location, Activity, Name, Sex, Age, Injury, Fatal (Y/N), Time, Species, Investigator or Source, pdf, Link, original order]
# Index: []

# %%
attacks['Year'].iloc[6079] = 0

# %%
attacks['Year'] = attacks['Year'].apply(int)

# %%
attacks.head()
# Out:
#   Case Number         Date  Year        Type    Country             Area  \
# 0  2018.06.25  25-Jun-2018  2018     Boating        USA       California
# 1  2018.06.18  18-Jun-2018  2018  Unprovoked        USA          Georgia
# 2  2018.06.09  09-Jun-2018  2018     Invalid        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  2018  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018  2018    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex  Age  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe   F   57
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely    F   11
# 2                    Habush, Oahu      Surfing      John Denges   M   48
# 3              Arrawarra Headland      Surfing              nan   M  nan
# 4                        La Ticla  Free diving   Gustavo Ramos    M  nan
#
#                                               Injury Fatal (Y/N)  \
# ...

# %%
attacks[attacks['Country'] == 'BRAZIL']
# Out:
#        Case Number                  Date  Year          Type Country  \
# 6     2018.06.03.a           03-Jun-2018  2018    Unprovoked  BRAZIL
# 27    2018.04.15.c           15-Apr-2018  2018    Unprovoked  BRAZIL
# 31    2018.04.10.R  Reported 10-Apr-2018  2018       Invalid  BRAZIL
# 44      2018.02.11           11-Feb-2018  2018       Invalid  BRAZIL
# 51      2018.01.12           12-Jan-2018  2018    Unprovoked  BRAZIL
# ...            ...                   ...   ...           ...     ...
# 5122    1927.10.25           25-Oct-1927  1927  Sea Disaster  BRAZIL
# 5746    1887.01.20           20-Jan-1887  1887  Sea Disaster  BRAZIL
# 5777  1884.04.38.R  Reported 28-Apr-1884  1884    Unprovoked  BRAZIL
# 5848    1878.02.02           02-Feb-1878  1878  Sea Disaster  BRAZIL
# 6101    1826.12.00              Dec-1826  1826    Unprovoked  BRAZIL
#
#                       Area                      Location  \
# 6               Pernambuco         Piedade Beach, Recife
# ...

# %%
attacks[attacks['Year'] == 0 ]
# Out:
#        Case Number                  Date  Year          Type  \
# 187   2017.01.08.R  Reported 08-Jan-2017     0       Invalid
# 6079  1836.08.19.R  Reported 19-Aug-1836     0    Unprovoked
# 6177     0000.0214          Ca. 214 B.C.     0    Unprovoked
# 6178     0000.0336         Ca. 336.B.C..     0    Unprovoked
# 6179     0000.0493              493 B.C.     0  Sea Disaster
# ...            ...                   ...   ...           ...
# 6297       ND.0005           Before 1903     0    Unprovoked
# 6298       ND.0004           Before 1903     0    Unprovoked
# 6299       ND.0003             1900-1905     0    Unprovoked
# 6300       ND.0002             1883-1889     0    Unprovoked
# 6301       ND.0001             1845-1853     0    Unprovoked
#
#                  Country               Area  \
# 187            AUSTRALIA         Queensland
# 6079             ENGLAND         Cumberland
# 6177                 NaN         Ionian Sea
# 6178              GREECE            Piraeus
# ...

# %%
attacks['original order'] = attacks['original order'].apply(int)

# %%
attacks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6302 entries, 0 to 6301
# Data columns (total 19 columns):
# Case Number               6302 non-null object
# Date                      6302 non-null object
# Year                      6302 non-null int64
# Type                      6298 non-null object
# Country                   6252 non-null object
# Area                      5847 non-null object
# Location                  5762 non-null object
# Activity                  5758 non-null object
# Name                      6302 non-null object
# Sex                       5735 non-null object
# Age                       6301 non-null object
# Injury                    6274 non-null object
# Fatal (Y/N)               5691 non-null object
# Time                      6302 non-null object
# Species                   3464 non-null object
# Investigator or Source    6285 non-null object
# pdf                       6302 non-null object
# Link                      6301 non-null object
# ...

# %%
attacks[attacks['Investigator or Source'].isnull()]
# Out:
#         Case Number                  Date  Year        Type       Country  \
# 119    2017.07.14.a           14-Jul-2017  2017  Unprovoked     AUSTRALIA
# 290    2016.04.07.b           07-Apr-2016  2016  Unprovoked           USA
# 382      2015.07.27           27-Jul-2015  2015         NaN     AUSTRALIA
# 631    2013.08.31.b           31-Aug-2013  2013  Unprovoked       BAHAMAS
# 1130     2009.04.28           28-Apr-2009  2009  Unprovoked           USA
# 1242   2008.06.28.a           28-Jun-2008  2008  Unprovoked  SOUTH AFRICA
# 2125     1999.04.22           22-Apr-1999  1999  Unprovoked     MAURITIUS
# 2144   1999.00.00.a                  1999  1999     Invalid           USA
# 2460   1994.00.00.a                  1994  1994  Unprovoked           USA
# 2648     1990.00.00                  1990  1990  Unprovoked           USA
# 3508   1967.09.07.a           07-Sep-1967  1967  Unprovoked           USA
# 3691     1964.03.00              Mar-1964  1964  Unprovoked       SENEGAL
# ...

# %%
attacks[attacks['Year'] == 0]
# Out:
#        Case Number                  Date  Year          Type  \
# 187   2017.01.08.R  Reported 08-Jan-2017     0       Invalid
# 6079  1836.08.19.R  Reported 19-Aug-1836     0    Unprovoked
# 6177     0000.0214          Ca. 214 B.C.     0    Unprovoked
# 6178     0000.0336         Ca. 336.B.C..     0    Unprovoked
# 6179     0000.0493              493 B.C.     0  Sea Disaster
# ...            ...                   ...   ...           ...
# 6297       ND.0005           Before 1903     0    Unprovoked
# 6298       ND.0004           Before 1903     0    Unprovoked
# 6299       ND.0003             1900-1905     0    Unprovoked
# 6300       ND.0002             1883-1889     0    Unprovoked
# 6301       ND.0001             1845-1853     0    Unprovoked
#
#                  Country               Area  \
# 187            AUSTRALIA         Queensland
# 6079             ENGLAND         Cumberland
# 6177                 NaN         Ionian Sea
# 6178              GREECE            Piraeus
# ...

# %%
attacks['Year'].iloc[6177] =

# %%
attacks[attacks['Year'] == 0]
# Out:
#      Case Number           Date  Year          Type             Country  \
# 6177   0000.0214   Ca. 214 B.C.     0    Unprovoked                 NaN
# 6178   0000.0336  Ca. 336.B.C..     0    Unprovoked              GREECE
# 6179   0000.0493       493 B.C.     0  Sea Disaster              GREECE
# 6180   0000.0725   Ca. 725 B.C.     0  Sea Disaster               ITALY
# 6181     ND-0154    Before 1939     0    Unprovoked              CANADA
# ...          ...            ...   ...           ...                 ...
# 6297     ND.0005    Before 1903     0    Unprovoked           AUSTRALIA
# 6298     ND.0004    Before 1903     0    Unprovoked           AUSTRALIA
# 6299     ND.0003      1900-1905     0    Unprovoked                 USA
# 6300     ND.0002      1883-1889     0    Unprovoked              PANAMA
# 6301     ND.0001      1845-1853     0    Unprovoked  CEYLON (SRI LANKA)
#
#                    Area                                           Location  \
# ...

# %%
attacks['Injury'].describe()
# Out:
# count      6274
# unique     3737
# top       FATAL
# freq        802
# Name: Injury, dtype: object

# %%
attacks['Species'].describe()
# Out:
# count            3464
# unique           1549
# top       White shark
# freq              163
# Name: Species, dtype: object

# %%
attacks[attacks['Species'].isnull()]
# Out:
#        Case Number         Date  Year        Type             Country  \
# 1       2018.06.18  18-Jun-2018  2018  Unprovoked                 USA
# 2       2018.06.09  09-Jun-2018  2018     Invalid                 USA
# 5     2018.06.03.b  03-Jun-2018  2018  Unprovoked           AUSTRALIA
# 9     2018.05.26.a  26-May-2018  2018  Unprovoked                 USA
# 11      2018.05.21  21-May-2018  2018  Unprovoked                 USA
# ...            ...          ...   ...         ...                 ...
# 6297       ND.0005  Before 1903     0  Unprovoked           AUSTRALIA
# 6298       ND.0004  Before 1903     0  Unprovoked           AUSTRALIA
# 6299       ND.0003    1900-1905     0  Unprovoked                 USA
# 6300       ND.0002    1883-1889     0  Unprovoked              PANAMA
# 6301       ND.0001    1845-1853     0  Unprovoked  CEYLON (SRI LANKA)
#
#                    Area                             Location         Activity  \
# ...
