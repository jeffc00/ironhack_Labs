# %% [markdown]
# ## Univariate and Bivariate Analysis

# %% [markdown]
# <b>Based on dataset</b>: https://www.kaggle.com/mustafaali96/weight-height

# %% [markdown]
# The variables used are:
# * Money
# * Height
# * Weight
# * Gender

# %% [markdown]
# ### Import libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %% [markdown]
# ### Load and read dataset

# %%
data = pd.read_csv('../Statistics_Visualizations/data/weight-height-money.csv')

data.head()
# Out:
#   Gender     Height      Weight       Money
# 0   Male  73.847017  241.893563   21.462754
# 1   Male  68.781904  162.310473   94.732358
# 2   Male  74.110105  212.740856  130.077362
# 3   Male  71.730978  220.042470  214.096064
# 4   Male  69.881796  206.349801  765.091245

# %% [markdown]
# ### Mean, median, mode, min, max and quantiles

# %% [markdown]
# Use the describe() function to understand the data.

# %%
data.describe()
# Out:
#              Height        Weight         Money
# count  10000.000000  10000.000000  1.000000e+04
# mean      66.367560    161.440357  6.311565e+02
# std        3.847528     32.108439  8.060481e+02
# min       54.263133     64.700127  1.735664e-07
# 25%       63.505620    135.818051  8.906720e+01
# 50%       66.318070    161.212928  3.390872e+02
# 75%       69.174262    187.169525  8.515404e+02
# max       78.998742    269.989699  8.168216e+03

# %% [markdown]
# ## Univariate Analysis

# %% [markdown]
# #### Gender count:
# Count how many Male and Female exist on this dataset.

# %%
# Hint: Another way to graphically see it would be to use: sns.countplot(data['Gender']).
# Also, if you've used value_counts, you can specify normalize=True to check percentages.

# %%
data.Gender.value_counts(normalize=True)
# Out:
# Female    0.5
# Male      0.5
# Name: Gender, dtype: float64

# %% [markdown]
# ### Considering only Height
#
# Create a pandas series of the Height variable

# %%
data['Height(cm)'] = data.Height.apply(lambda x: x*2.54) #transformin to centimeters.

# %%
height = data['Height(cm)']

# %%
height.shape
# Out:
# (10000,)

# %% [markdown]
# #### Histogram-plot
#
# Plot the histogram of the height

# %%
plt.figure(figsize=(12, 8))
height.hist();

# %% [markdown]
# #### Box-plot
#
# Plot the boxplot of the height

# %%
plt.figure(figsize=(10, 6))
plt.boxplot(height);

# %% [markdown]
# What do you think the distribution of height is like? Do you think it is normal for variables to behave like that in real life?

# %%
'''
Acho que seria possível pois a média parece ser um pouco alta mas para países nórdicos até que seria aceita.
'''

# %% [markdown]
# #### KDE distribution for height

# %% [markdown]
# Plot the kde distribution (without the hist distribution) of the height.

# %%
sns.kdeplot(height);

# %% [markdown]
# #### Analysis

# %% [markdown]
# As we can see we have a high count for height in the range 60 to 75. How many people fall off 3 standard deviations from the mean? Can you consider them outliers? Why is that?

# %%
outSup = height.mean()+3*height.std()
outSup
# Out:
# 197.89176605753795

# %%
outInf = height.mean()-3*height.std()
outInf
# Out:
# 139.25543749695396

# %%
data[(data['Height(cm)'] < outInf) | (data['Height(cm)'] > outSup)]
# Out:
#       Gender     Height      Weight        Money  Height(cm)
# 994     Male  78.095867  255.690835  1357.105000  198.363503
# 1317    Male  78.462053  227.342565     5.457968  199.293614
# 2014    Male  78.998742  269.989699   131.474470  200.656806
# 3285    Male  78.528210  253.889004     0.089663  199.461654
# 3757    Male  78.621374  245.733783   204.113245  199.698290
# 6624  Female  54.616858   71.393749   226.061310  138.726819
# 9285  Female  54.263133   64.700127   646.532185  137.828359

# %%
# expected results:
# Out:
#       Gender     Height      Weight
# 994     Male  78.095867  255.690835
# 1317    Male  78.462053  227.342565
# 2014    Male  78.998742  269.989699
# 3285    Male  78.528210  253.889004
# 3757    Male  78.621374  245.733783
# 6624  Female  54.616858   71.393749
# 9285  Female  54.263133   64.700127

# %% [markdown]
# # Now perform the same analysis for weight and money variables.

# %% [markdown]
# ### Considering only weight

# %% [markdown]
# Generate a variable call weight from the dataset

# %%
weight = data['Weight']
weight.shape
# Out:
# (10000,)

# %% [markdown]
# #### Histogram-plot

# %%
weight.hist();

# %% [markdown]
# #### Box-plot

# %%
plt.figure(figsize=(10,6))
sns.boxplot(weight);

# %% [markdown]
# #### KDE distribution for height

# %%
sns.kdeplot(weight);

# %%
outSupw = weight.mean()+3*weight.std()

# %%
outInfw = weight.mean()-3*weight.std()

# %%
data[(data['Weight'] < outInfw) | (data['Weight'] > outSupw)]
# Out:
#       Gender     Height      Weight       Money  Height(cm)
# 2014    Male  78.998742  269.989699  131.474470  200.656806
# 9285  Female  54.263133   64.700127  646.532185  137.828359

# %% [markdown]
# ### Analysis

# %% [markdown]
# Again, how many people fall off 3 standard deviations in both cases? Can you consider them outliers?

# %% [markdown]
# ## Bivariate Analysis

# %% [markdown]
# #### Considering both height and weight

# %% [markdown]
# Perform a scatterplot to check the relation between Height and Weight

# %%
plt.figure(figsize=(12, 8))
sns.scatterplot(data['Height(cm)'],data['Weight']);

# %% [markdown]
# Do the same plot, but color the markers by Gender

# %%
plt.figure(figsize=(12, 8))
sns.scatterplot(data['Height(cm)'],data['Weight'],markers=['Male', 'Female'], hue=data['Gender']);

# %% [markdown]
# Create a variable called gender_groupby to group data by 'Gender'. Do not specify any aggregation yet.

# %%
gender = data.groupby('Gender').

# %% [markdown]
# Run `gender_groupby.head()` to check the groups obtained.

# %%
gender.head()
# Out:
#       Gender     Height      Weight        Money  Height(cm)
# 0       Male  73.847017  241.893563    21.462754  187.571423
# 1       Male  68.781904  162.310473    94.732358  174.706036
# 2       Male  74.110105  212.740856   130.077362  188.239668
# 3       Male  71.730978  220.042470   214.096064  182.196685
# 4       Male  69.881796  206.349801   765.091245  177.499761
# 5000  Female  58.910732  102.088326    25.530452  149.633259
# 5001  Female  65.230013  141.305823   270.612186  165.684232
# 5002  Female  63.369004  131.041403  1114.256936  160.957270
# 5003  Female  64.479997  128.171511  2194.127692  163.779193
# 5004  Female  61.793096  129.781407   462.814462  156.954464

# %% [markdown]
# Run gender_groupby.describe() to check the statistics for each group. Do you know how one could enhance the visualization of this result?

# %%
gender.describe()
# Out:
#         Height                                                        \
#          count       mean       std        min        25%        50%
# Gender
# Female  5000.0  63.708774  2.696284  54.263133  61.894441  63.730924
# Male    5000.0  69.026346  2.863362  58.406905  67.174679  69.027709
#
#                               Weight              ...        Money  \
#               75%        max   count        mean  ...          75%
# Gender                                            ...
# Female  65.563565  73.389586  5000.0  135.860093  ...  1015.017353
# Male    70.988744  78.998742  5000.0  187.020621  ...   667.073116
#
#                     Height(cm)                                                \
#                 max      count        mean       std         min         25%
# Gender
# Female  7347.139257     5000.0  161.820285  6.848561  137.828359  157.211881
# Male    8168.216190     5000.0  175.326919  7.272940  148.353539  170.623685
#
#
#                50%         75%         max
# Gender
# Female  161.876547  166.531456  186.409548
# Male    175.330380  180.311409  200.656806
#
# [2 rows x 32 columns]

# %% [markdown]
# ### Distribution plots

# %% [markdown]
# #### Considering both gender and height
#
# Plot the distribution of the variable Height in the same plot breaking them down by 'Gender'

# %%
# Hint: You can use FaceGrid and map from sns or plot twice in the same axis

# %%
# using Facetgrid and map

# %%
# plotting sns.distplot twice

# %% [markdown]
# #### Considering both gender and weight and gender and money
#
# Do the same for the weight and money variable

# %%
# Hint, for the Money variable, try specifying hist=False

# %% [markdown]
# ### Boxplot

# %% [markdown]
# #### Gender vs Height
#
# Plot the boxplot considering the x-axis as Gender and y-axis as Height

# %%
plt.figure(figsize=(12, 8))

# %%
plt.figure(figsize=(12, 8))

# %% [markdown]
# #### Gender vs Weight

# %%
plt.figure(figsize=(12, 8))

# %% [markdown]
# ### Violin Plot
#
# Plot the Violin Plot for Height, Weight and Money

# %% [markdown]
# Height

# %%
plt.figure(figsize=(12, 8))

# %% [markdown]
# Weight

# %%
plt.figure(figsize=(12, 8))

# %% [markdown]
# Money

# %%
plt.figure(figsize=(12, 8))

# %% [markdown]
# ### Multivariate Analysis

# %% [markdown]
# Use sns.pairplot to see all combinations so far. Use `hue = 'Gender`.
#
# Note that in a real problem, pairplot starts to get messy since there can be countless number of variables in a dataset. Use it wisely.
